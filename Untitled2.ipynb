# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav2323/gaurav2323/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
consumer_key ="G3c2iZTlxqO863YsL7YfS5eRV"
consumer_secret ="aBnLtMy3AdT2V36QyUnAMvXkgZJbbiDqsgk98tn9f6V9ZFFGaJ"
access_token ="2468030390-41RealfqJgbUSKFJvP8GViFwU4ChjnpzSDIXWdT"
access_token_secret ="WLJ03jOjZxanfIzCnc7oWT8V0Lpwok2NhTIdEDDGL9wH4"

# %%
auth= tweepy.OAuthHandler(consumer_key,consumer_secret)

# %%
auth.set_access_token(access_token,access_token_secret)

# %%
api_connect=tweepy.API(auth)

# %%
number_of_tweets = 200
tweets=[]
likes=[]
time=[]
for i in tweepy.Cursor(api.user_timeline, id="elonmusk", tweet_mode="extended").items(number_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)

df= pd.DataFrame({'tweets':tweets, 'likes':likes, 'time':time})

# %%
#df.to_csv('narendra_modi.csv', index= False)

# %%
df
# Out:
#                                                tweets  ...                time
# 0   @stevenmarkryan Tesla will support FSD licensi...  ... 2022-01-28 17:51:33
# 1   Disney in the streets,\nEuphoria in the sheets...  ... 2022-01-28 17:44:30
# 2                              @archillect I have one  ... 2022-01-28 17:39:25
# 3   @stevenmarkryan Given how hard insanely FSD is...  ... 2022-01-28 01:54:29
# 4   @StockSwingAlert @cybrtrkguy I have a feeling ...  ... 2022-01-28 00:10:47
# 5   And in the darkness bind them https://t.co/Bvx...  ... 2022-01-27 23:56:10
# 6   @guper777 Honestly, I would let the border reg...  ... 2022-01-27 23:46:25
# 7                           @cybrtrkguy Vote them out  ... 2022-01-27 23:41:28
# 8   If you scare people enough, they will demand r...  ... 2022-01-27 23:39:57
# 9   Seems odd that the UN still hasn’t released 20...  ... 2022-01-27 22:24:24
# 10  @jayvasdigital Freedom is being stripped away ...  ... 2022-01-27 22:05:43
# ...

# %%
import textblob
Positive= 0
Negative= 0
Neutral = 0

for tweet in tweet_data:
  analysis= TextBlob(tweet.text)
  print(analysis.sentiment)
  if analysis.sentiment.polarity > 0:
    print ('Positive')
    Positive= Positive+1
  elif analysis.sentiment.polarity == 0:
    print ('Neutral')
    Neutral= Neutral+1
  else:
      print("Negative")
      Negative= Negative+1
    
plt.xlabel("Tag")
plt.ylabel("Polarity")
plt.pie([Positive, Negative,Neutral] , labels= [ "Positive", "Negative", " Neutral"], autopct="%1.1f%%" )
plt.show()
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.12424242424242422, subjectivity=0.43636363636363634)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Positive
